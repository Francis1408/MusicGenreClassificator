# %%
# Method 1. Nearest Centroid Classifier
# Similar to the Cluster Method for Unsupervised learning
# we can obtain the Centroid of each genre of music
# We get a vector in space of N dimensions according to the number of relevant characteristics of the music
# If a new song comes, we look for the nearest Centroid to determine which genre is the most appopiate one
# Of course, this means that some data measurements will have to be normalized.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mode

song_data = pd.read_csv('../data/songs_data.csv')
song_data.head()
# Out:
#                  track_id                    track_name   track_artist  \
# 0  6ho0GyrWZN3mhi9zVRW7xi                     Losing It         FISHER
# 1  4bYJKHG6KLdGzHQRJMaFc8        Rock And Roll All Nite           KISS
# 2  1VGlMYqPO1LHyclvfIMvWI  Snälla bli min (Hjalm Remix)  Robin Lukovic
# 3  6BbINUfGabVyiNFJpQXn3x                        Wicked         Future
# 4  1Ly0ssAgeM7YqdHptao8Oe                      Paranoid  Black Sabbath
#
#    track_popularity genre  danceability  energy  key  loudness  mode  \
# 0                79   edm         0.760   0.964    2    -5.844     1
# 1                 3  rock         0.581   0.831    1    -8.045     1
# 2                 0   edm         0.661   0.760    8    -4.769     1
# 3                62   rap         0.718   0.679   11    -5.899     0
# 4                15  rock         0.426   0.619    4   -11.501     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0576      0.001820           0.70000    0.0974    0.641  125.000
# 1       0.1070      0.045800           0.00000    0.0782    0.885  144.684
# 2       0.0268      0.000406           0.04070    0.6110    0.439   99.993
# 3       0.0706      0.001910           0.01040    0.3850    0.205  157.970
# 4       0.0722      0.000084           0.00239    0.1700    0.382  162.721
#
#    duration_ms
# 0       248036
# 1       168160
# 2       271238
# 3       173347
# 4       168440

# %%
song_data['genre'].unique()
# Out:
# array(['edm', 'rock', 'rap', 'latin', 'r&b', 'pop'], dtype=object)

# %%
edm_data = song_data[song_data['genre']=='edm']
rock_data = song_data[song_data['genre']=='rock']
rap_data = song_data[song_data['genre']=='rap']
latin_data = song_data[song_data['genre']=='latin']
rb_data = song_data[song_data['genre']=='r&b']
pop_data = song_data[song_data['genre']=='pop']

# %%
global_mean = song_data.mean(numeric_only = True)
global_std = song_data.std(numeric_only = True)

edm_mean = edm_data.mean(numeric_only = True)
rock_mean = rock_data.mean(numeric_only = True)
rap_mean = rap_data.mean(numeric_only = True)
latin_mean = latin_data.mean(numeric_only = True)
rb_mean = rb_data.mean(numeric_only = True)
pop_mean = pop_data.mean(numeric_only = True)

normalized_edm = (edm_mean-global_mean)/global_std
normalized_rock = (rock_mean-global_mean)/global_std
normalized_rap = (rap_mean-global_mean)/global_std
normalized_latin=(latin_mean-global_mean)/global_std
normalized_rb = (rb_mean-global_mean)/global_std
normalized_pop=(pop_mean-global_mean)/global_std

vector_edm = normalized_edm.values
vector_rock = normalized_rock.values
vector_rap = normalized_rap.values
vector_latin=normalized_latin.values
vector_rb = normalized_rb.values
vector_pop= normalized_pop.values

print(vector_rock)
# Out:
# [ 0.01383964 -0.92447199  0.18832721 -0.03156749 -0.2452776   0.25637698
#  -0.48763444 -0.13295944 -0.10560696  0.08923148  0.0945206   0.15226529
#   0.35376681]

# %%
# Run the previous code once, then you can modify this one:
input_data = pd.read_csv('../data/Input_Song.csv')
input_data.head()
# Out:
#   track_id track_name track_artist  track_popularity  danceability  energy  \
# 0     none    Testing        Dante                70           0.7     0.6
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    5   -11.501     1          0.2          0.04               0.5       0.5
#
#    valence  tempo  duration_ms
# 0    0.452    125       168440

# %%
normalized_input = (input_data.select_dtypes(include='number')-global_mean)/global_std

# %%
vector_input = normalized_input.values
magnitude_list =[];
magnitude_list.append(np.linalg.norm(vector_input-vector_edm))
magnitude_list.append(np.linalg.norm(vector_input-vector_rock))
magnitude_list.append(np.linalg.norm(vector_input-vector_rap))
magnitude_list.append(np.linalg.norm(vector_input-vector_latin))
magnitude_list.append(np.linalg.norm(vector_input-vector_rb))
magnitude_list.append(np.linalg.norm(vector_input-vector_pop))

# %%
min_mag_index = np.argmin(magnitude_list)
print("The song is ")
if(min_mag_index==0):
    print("EDM")
elif(min_mag_index==1):
    print("Rock")
elif(min_mag_index==2):
    print("Rap")
elif(min_mag_index==3):
    print("latin")
elif(min_mag_index==4):
    print("r&b")
elif(min_mag_index==5):
    print("pop")
# Out:
# The song is
# Rap
